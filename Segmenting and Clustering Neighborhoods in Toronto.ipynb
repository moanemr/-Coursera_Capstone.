# %%
import pandas as pd
import numpy as np
import requests

# %%
wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wiki_page = requests.get(wiki)

# %%
wiki_raw = pd.read_html(wiki_page.content, header = 0)[0]

# %%
df = wiki_raw

# %%
df.reset_index(inplace = True)
df.head()
# Out:
#    index                                    M1ANot assigned  \
# 0      0                    M1BScarborough(Malvern / Rouge)
# 1      1  M1CScarborough(Rouge Hill / Port Union / Highl...
# 2      2  M1EScarborough(Guildwood / Morningside / West ...
# 3      3                             M1GScarborough(Woburn)
# 4      4                          M1HScarborough(Cedarbrae)
#
#                     M2ANot assigned  \
# 0                   M2BNot assigned
# 1                   M2CNot assigned
# 2                   M2ENot assigned
# 3                   M2GNot assigned
# 4  M2HNorth York(Hillcrest Village)
#
#                             M3ANorth York(Parkwoods)  \
# 0                      M3BNorth York(Don Mills)North
# 1     M3CNorth York(Don Mills)South(Flemingdon Park)
# 2                                    M3ENot assigned
# 3                                    M3GNot assigned
# 4  M3HNorth York(Bathurst Manor / Wilson Heights ...
#
#                   M4ANorth York(Victoria Village)  \
# 0  M4BEast York(Parkview Hill / Woodbine Gardens)
# 1                  M4CEast York(Woodbine Heights)
# 2                    M4EEast Toronto(The Beaches)
# 3                           M4GEast York(Leaside)
# 4                  M4HEast York(Thorncliffe Park)
#
#    M5ADowntown Toronto(Regent Park / Harbourfront)  \
# 0    M5BDowntown Toronto(Garden District, Ryerson)
# 1              M5CDowntown Toronto(St. James Town)
# 2                 M5EDowntown Toronto(Berczy Park)
# 3          M5GDowntown Toronto(Central Bay Street)
# 4  M5HDowntown Toronto(Richmond / Adelaide / King)
#
#   M6ANorth York(Lawrence Manor / Lawrence Heights)  \
# 0                         M6BNorth York(Glencairn)
# 1                      M6CYork(Humewood-Cedarvale)
# 2                     M6EYork(Caledonia-Fairbanks)
# 3                    M6GDowntown Toronto(Christie)
# 4   M6HWest Toronto(Dufferin / Dovercourt Village)
#
#   M7AQueen's Park(Ontario Provincial Government)  M8ANot assigned  \
# 0                                M7BNot assigned  M8BNot assigned
# 1                                M7CNot assigned  M8CNot assigned
# 2                                M7ENot assigned  M8ENot assigned
# 3                                M7GNot assigned  M8GNot assigned
# 4                                M7HNot assigned  M8HNot assigned
#
#                       M9AEtobicoke(Islington Avenue)
# 0  M9BEtobicoke(West Deane Park / Princess Garden...
# 1  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 2                                    M9ENot assigned
# 3                                    M9GNot assigned
# 4                                    M9HNot assigned

# %%
df.groupby('M6ANorth York(Lawrence Manor / Lawrence Heights)').first()
# Out:
#                                                     index  \
# M6ANorth York(Lawrence Manor / Lawrence Heights)
# M6BNorth York(Glencairn)                                0
# M6CYork(Humewood-Cedarvale)                             1
# M6EYork(Caledonia-Fairbanks)                            2
# M6GDowntown Toronto(Christie)                           3
# M6HWest Toronto(Dufferin / Dovercourt Village)          4
# M6JWest Toronto(Little Portugal / Trinity)              5
# M6KWest Toronto(Brockton / Parkdale Village / E...      6
# M6LNorth York(North Park / Maple Leaf Park / Up...      7
# M6MYork(Del Ray / Mount Dennis / Keelsdale and ...      8
# M6NYork(Runnymede / The Junction North)                 9
# M6PWest Toronto(High Park / The Junction South)        10
# M6RWest Toronto(Parkdale / Roncesvalles)               11
# M6SWest Toronto(Runnymede / Swansea)                   12
# M6TNot assigned                                        13
# M6VNot assigned                                        14
# M6WNot assigned                                        15
# M6XNot assigned                                        16
# M6YNot assigned                                        17
# M6ZNot assigned                                        18
#
#                                                                                       M1ANot assigned  \
# M6ANorth York(Lawrence Manor / Lawrence Heights)
# M6BNorth York(Glencairn)                                              M1BScarborough(Malvern / Rouge)
# M6CYork(Humewood-Cedarvale)                         M1CScarborough(Rouge Hill / Port Union / Highl...
# M6EYork(Caledonia-Fairbanks)                        M1EScarborough(Guildwood / Morningside / West ...
# M6GDowntown Toronto(Christie)                                                  M1GScarborough(Woburn)
# M6HWest Toronto(Dufferin / Dovercourt Village)                              M1HScarborough(Cedarbrae)
# M6JWest Toronto(Little Portugal / Trinity)                        M1JScarborough(Scarborough Village)
# M6KWest Toronto(Brockton / Parkdale Village / E...  M1KScarborough(Kennedy Park / Ionview / East B...
# M6LNorth York(North Park / Maple Leaf Park / Up...  M1LScarborough(Golden Mile / Clairlea / Oakridge)
# M6MYork(Del Ray / Mount Dennis / Keelsdale and ...  M1MScarborough(Cliffside / Cliffcrest / Scarbo...
# M6NYork(Runnymede / The Junction North)                  M1NScarborough(Birch Cliff / Cliffside West)
# M6PWest Toronto(High Park / The Junction South)     M1PScarborough(Dorset Park / Wexford Heights /...
# M6RWest Toronto(Parkdale / Roncesvalles)                           M1RScarborough(Wexford / Maryvale)
# M6SWest Toronto(Runnymede / Swansea)                                        M1SScarborough(Agincourt)
# M6TNot assigned                                     M1TScarborough(Clarks Corners / Tam O'Shanter ...
# M6VNot assigned                                     M1VScarborough(Milliken / Agincourt North / St...
# M6WNot assigned                                        M1WScarborough(Steeles West / L'Amoreaux West)
# M6XNot assigned                                                           M1XScarborough(Upper Rouge)
# M6YNot assigned                                                                       M1YNot assigned
# M6ZNot assigned                                                                       M1ZNot assigned
#
#                                                                                   M2ANot assigned  \
# M6ANorth York(Lawrence Manor / Lawrence Heights)
# M6BNorth York(Glencairn)                                                          M2BNot assigned
# M6CYork(Humewood-Cedarvale)                                                       M2CNot assigned
# M6EYork(Caledonia-Fairbanks)                                                      M2ENot assigned
# M6GDowntown Toronto(Christie)                                                     M2GNot assigned
# M6HWest Toronto(Dufferin / Dovercourt Village)                   M2HNorth York(Hillcrest Village)
# M6JWest Toronto(Little Portugal / Trinity)          M2JNorth York(Fairview / Henry Farm / Oriole)
# M6KWest Toronto(Brockton / Parkdale Village / E...                 M2KNorth York(Bayview Village)
# M6LNorth York(North Park / Maple Leaf Park / Up...       M2LNorth York(York Mills / Silver Hills)
# M6MYork(Del Ray / Mount Dennis / Keelsdale and ...        M2MNorth York(Willowdale / Newtonbrook)
# M6NYork(Runnymede / The Junction North)                            M2NNorth York(Willowdale)South
# M6PWest Toronto(High Park / The Junction South)                    M2PNorth York(York Mills West)
# M6RWest Toronto(Parkdale / Roncesvalles)                            M2RNorth York(Willowdale)West
# M6SWest Toronto(Runnymede / Swansea)                                              M2SNot assigned
# M6TNot assigned                                                                   M2TNot assigned
# M6VNot assigned                                                                   M2VNot assigned
# M6WNot assigned                                                                   M2WNot assigned
# M6XNot assigned                                                                   M2XNot assigned
# M6YNot assigned                                                                   M2YNot assigned
# M6ZNot assigned                                                                   M2ZNot assigned
#
#                                                                              M3ANorth York(Parkwoods)  \
# M6ANorth York(Lawrence Manor / Lawrence Heights)
# M6BNorth York(Glencairn)                                                M3BNorth York(Don Mills)North
# M6CYork(Humewood-Cedarvale)                            M3CNorth York(Don Mills)South(Flemingdon Park)
# M6EYork(Caledonia-Fairbanks)                                                          M3ENot assigned
# M6GDowntown Toronto(Christie)                                                         M3GNot assigned
# M6HWest Toronto(Dufferin / Dovercourt Village)      M3HNorth York(Bathurst Manor / Wilson Heights ...
# M6JWest Toronto(Little Portugal / Trinity)            M3JNorth York(Northwood Park / York University)
# M6KWest Toronto(Brockton / Parkdale Village / E...         M3KNorth York(Downsview)East (CFB Toronto)
# M6LNorth York(North Park / Maple Leaf Park / Up...                       M3LNorth York(Downsview)West
# M6MYork(Del Ray / Mount Dennis / Keelsdale and ...                    M3MNorth York(Downsview)Central
# M6NYork(Runnymede / The Junction North)                             M3NNorth York(Downsview)Northwest
# M6PWest Toronto(High Park / The Junction South)                                       M3PNot assigned
# M6RWest Toronto(Parkdale / Roncesvalles)                                              M3RNot assigned
# M6SWest Toronto(Runnymede / Swansea)                                                  M3SNot assigned
# M6TNot assigned                                                                       M3TNot assigned
# M6VNot assigned                                                                       M3VNot assigned
# M6WNot assigned                                                                       M3WNot assigned
# M6XNot assigned                                                                       M3XNot assigned
# M6YNot assigned                                                                       M3YNot assigned
# M6ZNot assigned                                                                       M3ZNot assigned
#
#                                                                       M4ANorth York(Victoria Village)  \
# M6ANorth York(Lawrence Manor / Lawrence Heights)
# M6BNorth York(Glencairn)                               M4BEast York(Parkview Hill / Woodbine Gardens)
# M6CYork(Humewood-Cedarvale)                                            M4CEast York(Woodbine Heights)
# M6EYork(Caledonia-Fairbanks)                                             M4EEast Toronto(The Beaches)
# M6GDowntown Toronto(Christie)                                                   M4GEast York(Leaside)
# M6HWest Toronto(Dufferin / Dovercourt Village)                         M4HEast York(Thorncliffe Park)
# M6JWest Toronto(Little Portugal / Trinity)                M4JEast YorkEast Toronto(The Danforth East)
# M6KWest Toronto(Brockton / Parkdale Village / E...     M4KEast Toronto(The Danforth West / Riverdale)
# M6LNorth York(North Park / Maple Leaf Park / Up...   M4LEast Toronto(India Bazaar / The Beaches West)
# M6MYork(Del Ray / Mount Dennis / Keelsdale and ...                   M4MEast Toronto(Studio District)
# M6NYork(Runnymede / The Junction North)                             M4NCentral Toronto(Lawrence Park)
# M6PWest Toronto(High Park / The Junction South)                  M4PCentral Toronto(Davisville North)
# M6RWest Toronto(Parkdale / Roncesvalles)                       M4RCentral Toronto(North Toronto West)
# M6SWest Toronto(Runnymede / Swansea)                                   M4SCentral Toronto(Davisville)
# M6TNot assigned                                      M4TCentral Toronto(Moore Park / Summerhill East)
# M6VNot assigned                                     M4VCentral Toronto(Summerhill West / Rathnelly...
# M6WNot assigned                                                         M4WDowntown Toronto(Rosedale)
# M6XNot assigned                                     M4XDowntown Toronto(St. James Town / Cabbagetown)
# M6YNot assigned                                             M4YDowntown Toronto(Church and Wellesley)
# M6ZNot assigned                                                                       M4ZNot assigned
#
#                                                       M5ADowntown Toronto(Regent Park / Harbourfront)  \
# M6ANorth York(Lawrence Manor / Lawrence Heights)
# M6BNorth York(Glencairn)                                M5BDowntown Toronto(Garden District, Ryerson)
# M6CYork(Humewood-Cedarvale)                                       M5CDowntown Toronto(St. James Town)
# M6EYork(Caledonia-Fairbanks)                                         M5EDowntown Toronto(Berczy Park)
# M6GDowntown Toronto(Christie)                                 M5GDowntown Toronto(Central Bay Street)
# M6HWest Toronto(Dufferin / Dovercourt Village)        M5HDowntown Toronto(Richmond / Adelaide / King)
# M6JWest Toronto(Little Portugal / Trinity)          M5JDowntown Toronto(Harbourfront East / Union ...
# M6KWest Toronto(Brockton / Parkdale Village / E...  M5KDowntown Toronto(Toronto Dominion Centre / ...
# M6LNorth York(North Park / Maple Leaf Park / Up...  M5LDowntown Toronto(Commerce Court / Victoria ...
# M6MYork(Del Ray / Mount Dennis / Keelsdale and ...  M5MNorth York(Bedford Park / Lawrence Manor East)
# M6NYork(Runnymede / The Junction North)                                  M5NCentral Toronto(Roselawn)
# M6PWest Toronto(High Park / The Junction South)          M5PCentral Toronto(Forest Hill North & West)
# M6RWest Toronto(Parkdale / Roncesvalles)            M5RCentral Toronto(The Annex / North Midtown /...
# M6SWest Toronto(Runnymede / Swansea)                M5SDowntown Toronto(University of Toronto / Ha...
# M6TNot assigned                                     M5TDowntown Toronto(Kensington Market / Chinat...
# M6VNot assigned                                     M5VDowntown Toronto(CN Tower / King and Spadin...
# M6WNot assigned                                     M5WDowntown TorontoStn A PO Boxes25 The Esplan...
# M6XNot assigned                                     M5XDowntown Toronto(First Canadian Place / Und...
# M6YNot assigned                                                                       M5YNot assigned
# M6ZNot assigned                                                                       M5ZNot assigned
#
#                                                        M7AQueen's Park(Ontario Provincial Government)  \
# M6ANorth York(Lawrence Manor / Lawrence Heights)
# M6BNorth York(Glencairn)                                                              M7BNot assigned
# M6CYork(Humewood-Cedarvale)                                                           M7CNot assigned
# M6EYork(Caledonia-Fairbanks)                                                          M7ENot assigned
# M6GDowntown Toronto(Christie)                                                         M7GNot assigned
# M6HWest Toronto(Dufferin / Dovercourt Village)                                        M7HNot assigned
# M6JWest Toronto(Little Portugal / Trinity)                                            M7JNot assigned
# M6KWest Toronto(Brockton / Parkdale Village / E...                                    M7KNot assigned
# M6LNorth York(North Park / Maple Leaf Park / Up...                                    M7LNot assigned
# M6MYork(Del Ray / Mount Dennis / Keelsdale and ...                                    M7MNot assigned
# M6NYork(Runnymede / The Junction North)                                               M7NNot assigned
# M6PWest Toronto(High Park / The Junction South)                                       M7PNot assigned
# M6RWest Toronto(Parkdale / Roncesvalles)            M7RMississaugaCanada Post Gateway Processing C...
# M6SWest Toronto(Runnymede / Swansea)                                                  M7SNot assigned
# M6TNot assigned                                                                       M7TNot assigned
# M6VNot assigned                                                                       M7VNot assigned
# M6WNot assigned                                                                       M7WNot assigned
# M6XNot assigned                                                                       M7XNot assigned
# M6YNot assigned                                     M7YEast TorontoBusiness reply mail Processing ...
# M6ZNot assigned                                                                       M7ZNot assigned
#
#                                                                                       M8ANot assigned  \
# M6ANorth York(Lawrence Manor / Lawrence Heights)
# M6BNorth York(Glencairn)                                                              M8BNot assigned
# M6CYork(Humewood-Cedarvale)                                                           M8CNot assigned
# M6EYork(Caledonia-Fairbanks)                                                          M8ENot assigned
# M6GDowntown Toronto(Christie)                                                         M8GNot assigned
# M6HWest Toronto(Dufferin / Dovercourt Village)                                        M8HNot assigned
# M6JWest Toronto(Little Portugal / Trinity)                                            M8JNot assigned
# M6KWest Toronto(Brockton / Parkdale Village / E...                                    M8KNot assigned
# M6LNorth York(North Park / Maple Leaf Park / Up...                                    M8LNot assigned
# M6MYork(Del Ray / Mount Dennis / Keelsdale and ...                                    M8MNot assigned
# M6NYork(Runnymede / The Junction North)                                               M8NNot assigned
# M6PWest Toronto(High Park / The Junction South)                                       M8PNot assigned
# M6RWest Toronto(Parkdale / Roncesvalles)                                              M8RNot assigned
# M6SWest Toronto(Runnymede / Swansea)                                                  M8SNot assigned
# M6TNot assigned                                                                       M8TNot assigned
# M6VNot assigned                                     M8VEtobicoke(New Toronto / Mimico South / Humb...
# M6WNot assigned                                                 M8WEtobicoke(Alderwood / Long Branch)
# M6XNot assigned                                     M8XEtobicoke(The Kingsway / Montgomery Road / ...
# M6YNot assigned                                     M8YEtobicoke(Old Mill South / King's Mill Park...
# M6ZNot assigned                                     M8ZEtobicoke(Mimico NW / The Queensway West / ...
#
#                                                                        M9AEtobicoke(Islington Avenue)
# M6ANorth York(Lawrence Manor / Lawrence Heights)
# M6BNorth York(Glencairn)                            M9BEtobicoke(West Deane Park / Princess Garden...
# M6CYork(Humewood-Cedarvale)                         M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# M6EYork(Caledonia-Fairbanks)                                                          M9ENot assigned
# M6GDowntown Toronto(Christie)                                                         M9GNot assigned
# M6HWest Toronto(Dufferin / Dovercourt Village)                                        M9HNot assigned
# M6JWest Toronto(Little Portugal / Trinity)                                            M9JNot assigned
# M6KWest Toronto(Brockton / Parkdale Village / E...                                    M9KNot assigned
# M6LNorth York(North Park / Maple Leaf Park / Up...                       M9LNorth York(Humber Summit)
# M6MYork(Del Ray / Mount Dennis / Keelsdale and ...                   M9MNorth York(Humberlea / Emery)
# M6NYork(Runnymede / The Junction North)                                               M9NYork(Weston)
# M6PWest Toronto(High Park / The Junction South)                               M9PEtobicoke(Westmount)
# M6RWest Toronto(Parkdale / Roncesvalles)            M9REtobicoke(Kingsview Village / St. Phillips ...
# M6SWest Toronto(Runnymede / Swansea)                                                  M9SNot assigned
# M6TNot assigned                                                                       M9TNot assigned
# M6VNot assigned                                     M9VEtobicoke(South Steeles / Silverstone / Hum...
# M6WNot assigned                                     M9WEtobicokeNorthwest(Clairville / Humberwood ...
# M6XNot assigned                                                                       M9XNot assigned
# M6YNot assigned                                                                       M9YNot assigned
# M6ZNot assigned                                                                       M9ZNot assigned

# %%
df.shape
# Out:
# (19, 10)
